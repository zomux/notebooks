# %% [markdown]
# # ベーズ統計入門
# ## 第四章 ベイズ判別問題とパターン認識
# ## Raphael Shu 2014.9

# %% [markdown]
# ## 内容
# - 4.1 メッセージと符号
# - 4.2 ベイズ決定
# - 4.3 正規分布をもつノイズ
# - 4.4 ミニマックス決定

# %% [markdown]
# # 背景説明

# %%
data = """
<svg width="580" height="400" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
 <!-- Created with Method Draw - http://github.com/duopixel/Method-Draw/ -->
 <g>
  <title>background</title>
  <rect fill="#fff" id="canvas_background" height="402" width="582" y="-1" x="-1"/>
  <g display="none" overflow="visible" y="0" x="0" height="100%" width="100%" id="canvasGrid">
   <rect fill="url(#gridpattern)" stroke-width="0" y="0" x="0" height="100%" width="100%"/>
  </g>
 </g>
 <g>
  <title>Layer 1</title>
  <image xlink:href="data:image/png;base64,..." id="svg_2" height="101" width="130" y="84.5" x="67"/>
  <image xlink:href="data:image/png;base64,..." id="svg_3" height="105" width="115" y="247.5" x="77.5"/>
  <path transform="rotate(90 262.97 142.187)" id="svg_4" d="m239.469986,142.06987l23.499985,-48.383087l23.5,48.383087l-11.749756,0l0,48.616898l-23.500061,0l0,-48.616898l-11.750168,0z" stroke-width="1.5" stroke="#000" fill="#000000"/>
  <path transform="rotate(90 260.97 293.187)" id="svg_5" d="m237.469986,293.069885l23.499985,-48.383102l23.5,48.383102l-11.749756,0l0,48.616882l-23.500061,0l0,-48.616882l-11.750168,0z" stroke-width="1.5" stroke="#000" fill="#000000"/>
  <text xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_8" y="140" x="382.5" fill-opacity="null" stroke-opacity="null" stroke-width="0" stroke="#000" fill="#000000">yes (1)</text>
  <text xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_9" y="305" x="389.5" fill-opacity="null" stroke-opacity="null" stroke-width="0" stroke="#000" fill="#000000">no (0)</text>
  <text style="cursor: move;" font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_10" y="55" x="82.5" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">実世界</text>
  <text style="cursor: move;" font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_12" y="55" x="372.758514" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">データ</text>
 </g>
</svg>
"""
from IPython.core.display import display, Image, SVG
display(SVG(data))

# %% [markdown]
# # 4.1 メッセージと符号

# %%
data = """
<svg width="580" height="400" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
 <!-- Created with Method Draw - http://github.com/duopixel/Method-Draw/ -->
 <g>
  <title>background</title>
  <rect fill="#fff" id="canvas_background" height="402" width="582" y="-1" x="-1"/>
  <g display="none" overflow="visible" y="0" x="0" height="100%" width="100%" id="canvasGrid">
   <rect fill="url(#gridpattern)" stroke-width="0" y="0" x="0" height="100%" width="100%"/>
  </g>
 </g>
 <g>
  <title>Layer 1</title>
  <image xlink:href="data:image/png;base64,..." id="svg_2" height="101" width="130" y="114.5" x="13"/>
  <image xlink:href="data:image/png;base64,..." id="svg_3" height="105" width="115" y="230.5" x="22.5"/>
  <path stroke="#000" transform="rotate(90 249.97 163.187)" id="svg_4" d="m226.469986,162.980682l23.499985,-85.293907l23.5,85.293907l-11.749756,0l0,85.706085l-23.500061,0l0,-85.706085l-11.750168,0z" stroke-width="1.5" fill="#000000"/>
  <path stroke="#000" transform="rotate(90 249.47 278.187)" id="svg_5" d="m225.969971,277.97467l23.499985,-87.787903l23.500015,87.787903l-11.749756,0l0,88.212097l-23.500076,0l0,-88.212097l-11.750168,0z" stroke-width="1.5" fill="#000000"/>
  <text xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_8" y="197" x="381.5" fill-opacity="null" stroke-opacity="null" stroke-width="0" stroke="#000" fill="#000000">(1,1,-1,-1,-1)</text>
  <text font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_10" y="102" x="31.5" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">実世界</text>
  <text font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_12" y="106" x="199.758514" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">符号化</text>
  <text style="cursor: move;" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_13" y="311" x="380.5" fill-opacity="null" stroke-opacity="null" stroke-width="0" stroke="#000" fill="#000000">(1,-1,1,-1,1)</text>
  <text font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_14" y="65" x="419.758514" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">符号</text>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_16" y2="125" x2="436.928216" y1="125" x1="379.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_19" y2="154.160256" x2="436.5" y1="126" x1="436.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_20" y2="155" x2="437.5" y1="155" x1="495.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke="#000" stroke-linecap="null" stroke-linejoin="null" id="svg_21" y2="238" x2="401.92822" y1="238" x1="381.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_22" y2="267.160256" x2="401.5" y1="239" x1="401.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_24" y2="267.160256" x2="421.5" y1="239" x1="421.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke="#000" stroke-linecap="null" stroke-linejoin="null" id="svg_25" y2="266" x2="420.92822" y1="266" x1="400.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" fill="none"/>
  <line stroke="#000" stroke-linecap="null" stroke-linejoin="null" id="svg_26" y2="239" x2="442.92822" y1="239" x1="422.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" fill="none"/>
  <line stroke="#000" stroke-linecap="null" stroke-linejoin="null" id="svg_27" y2="238" x2="442.92822" y1="238" x1="422.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_28" y2="267.160256" x2="442.5" y1="239" x1="442.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_29" y2="267.160256" x2="462.5" y1="239" x1="462.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke="#000" stroke-linecap="null" stroke-linejoin="null" id="svg_30" y2="266" x2="461.92822" y1="266" x1="441.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" fill="none"/>
  <line stroke="#000" stroke-linecap="null" stroke-linejoin="null" id="svg_31" y2="239" x2="483.92822" y1="239" x1="463.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" fill="none"/>
 </g>
</svg>
"""
from IPython.core.display import display, Image, SVG
display(SVG(data))

# %% [markdown]
# - 符号化: メッセージ -> 符号
#
# - 復号化: 符号 -> メッセージ

# %% [markdown]
# ## ノイズ

# %%
data="""
<svg width="580" height="400" xmlns="http://www.w3.org/2000/svg">
 <!-- Created with Method Draw - http://github.com/duopixel/Method-Draw/ -->

 <g>
  <title>background</title>
  <rect fill="#fff" id="canvas_background" height="402" width="582" y="-1" x="-1"/>
  <g display="none" id="canvasGrid">
   <rect fill="url(#gridpattern)" stroke-width="0" y="0" x="0" height="100%" width="100%" id="svg_1"/>
  </g>
 </g>
 <g>
  <title>Layer 1</title>
  <path stroke="#000" transform="rotate(90 249.97 163.187)" id="svg_4" d="m226.46999,162.98068l23.49998,-85.2939l23.5,85.2939l-11.74976,0l0,85.7061l-23.50006,0l0,-85.7061l-11.75017,0z" stroke-width="1.5" fill="#000000"/>
  <text font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_12" y="106" x="199.75851" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">通信路</text>
  <text font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_14" y="107" x="48.75851" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">符号</text>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_16" y2="142" x2="84.92822" y1="142" x1="27.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_19" y2="171.16026" x2="84.5" y1="143" x1="84.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <line stroke-linecap="null" stroke-linejoin="null" id="svg_20" y2="172" x2="85.5" y1="172" x1="143.5" fill-opacity="null" stroke-opacity="null" stroke-width="1.5" stroke="#000" fill="none"/>
  <path fill="none" stroke="#000" stroke-width="0" stroke-opacity="null" fill-opacity="null" id="svg_9" d="m356.5,145c0,-1 0.81943,-0.98386 6,-6c6.18005,-5.9839 10,-14 13,-18c3,-4 3.69345,-7.5412 5,-7c1.84775,0.76537 0.49622,6.01761 0,13c-0.50125,7.05328 -1.38907,13.03746 -2,18c-0.50378,4.09221 -1,5 -1,5l0,-1l0,-1"/>
  <path d="m347.5,118c0,-1 -0.66251,-2.31001 1,-5c0.7435,-1.203 2.15225,-2.76537 4,-2c1.30655,0.5412 1,4 1,6c0,4 1,6 1,7c0,0 0.84723,-1.04132 2,-5c0.88412,-3.03616 2,-5 2,-6c0,-1 1,-1 1,-1c1,2 1,3 1,5c0,1 1.07611,1.38268 2,1c1.30655,-0.5412 2,-1 3,-1c2,0 2.29291,0.29289 3,1c0.70709,0.70711 1.29291,-1.29289 2,-2c0.70709,-0.70711 1.82443,0.09789 3,2c0.52573,0.85065 0,0 0,-1c0,-1 0.48627,-1.17625 1,1c0.4595,1.9465 0,3 0,5c0,0 1.29291,-0.70711 2,0c1.41422,1.41422 1,5 1,9c0,4 0.48627,6.82375 1,9c0.22977,0.97325 0.4588,1.69344 1,3c0.76538,1.84776 1.07611,2.61731 2,3c1.30655,0.5412 1.79395,-0.08743 4,-5c1.83203,-4.07967 4,-6 5,-8c0,0 0,1 0,4c0,4 0,8 0,9c0,1 1.07611,1.38269 2,1c2.61313,-1.0824 2,-4 3,-4c1,0 1,2 1,4c0,2 -0.70709,4.29289 0,5c0.70709,0.70711 1.9176,0.38687 3,3c0.76538,1.84776 1.4588,3.69344 2,5c0.38269,0.92387 2,1 3,1c2,0 5.21167,0.28587 8,-2c3.28101,-2.68979 6.297,-7.61383 9,-10c1.67633,-1.47984 3,-2 3,-2c1,1 2,4 3,7c1,3 1.77023,5.02675 2,6c0.51373,2.17625 2.29291,2.70711 3,2c1.41422,-1.41422 0.69345,-3.4588 2,-4c0.92389,-0.38269 1.4588,0.69344 2,2c1.14804,2.77164 0,3 0,3c1,0 2,0 3,0c0,0 1,0 2,0c1,0 2.14935,0.52573 3,0c1.9021,-1.17557 3.4588,-3.69344 4,-5c0.38269,-0.92387 1,-1 2,-1c1,0 2,0 2,-1c0,-1 0,-3 0,-6c0,-4 1,-9 1,-12c0,-2 0,-2 1,-2c1,0 2,0 3,0c1,0 2,0 2,-2c0,-1 1.29291,-1.70711 2,-1c0.70709,0.70711 0.14935,1.52573 1,1c1.9021,-1.17557 2.51929,-4.5582 5,-8c1.30746,-1.814 2,-3 2,-4c0,-1 0,-2 0,-3c0,-2 0,-3 0,-4l0,-1" id="svg_6" stroke-width="1.5" stroke="#000" fill="none"/>
  <text xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_7" y="210" x="339.5" stroke-width="0" stroke="#000" fill="#000000">(1, 1, -1, -1, 1)</text>
  <text style="cursor: move;" font-weight="bold" stroke="#000" xml:space="preserve" text-anchor="left" font-family="Helvetica, Arial, sans-serif" font-size="24" id="svg_8" y="88" x="341.75851" fill-opacity="null" stroke-opacity="null" stroke-width="0" fill="#000000">符号 + ノイズ</text>
 </g>
</svg>
"""
from IPython.core.display import display, Image, SVG
display(SVG(data))

# %% [markdown]
# # 4.2 ベイズ決定

# %%
data="""
<svg width="580" height="400" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
 <!-- Created with Method Draw - http://github.com/duopixel/Method-Draw/ -->

 <g>
  <title>background</title>
  <rect x="-1" y="-1" width="582" height="402" id="canvas_background" fill="#fff"/>
  <g id="canvasGrid" display="none">
   <rect id="svg_1" width="100%" height="100%" x="0" y="0" stroke-width="0" fill="url(#gridpattern)"/>
  </g>
 </g>
 <g>
  <title>Layer 1</title>
  <path fill="#000000" stroke-width="1.5" d="m226.46999,162.98068l23.49998,-85.2939l23.5,85.2939l-11.74976,0l0,85.7061l-23.50006,0l0,-85.7061l-11.75017,0z" id="svg_4" transform="translate(23 -48) rotate(64.9627 249.97 163.187)" stroke="#000"/>
  <path d="m36.5,175c0,-1 0.81943,-0.98386 6,-6c6.18005,-5.98389 10,-14 13,-18c3,-4 3.69345,-7.5412 5,-7c1.84775,0.76537 0.49622,6.01761 0,13c-0.50125,7.05328 -1.38907,13.03748 -2,18c-0.50378,4.09222 -1,5 -1,5l0,-1l0,-1" id="svg_9" fill-opacity="null" stroke-opacity="null" stroke-width="0" stroke="#000" fill="none"/>
  <path fill="none" stroke="#000" stroke-width="1.5" id="svg_6" d="m27.5,148c0,-1 -0.66251,-2.31001 1,-5c0.7435,-1.203 2.15225,-2.76538 4,-2c1.30655,0.5412 1,4 1,6c0,4 1,6 1,7c0,0 0.84723,-1.04132 2,-5c0.88412,-3.03616 2,-5 2,-6c0,-1 1,-1 1,-1c1,2 1,3 1,5c0,1 1.07611,1.38269 2,1c1.30655,-0.5412 2,-1 3,-1c2,0 2.29291,0.29289 3,1c0.70709,0.70711 1.29291,-1.29289 2,-2c0.70709,-0.70711 1.82443,0.0979 3,2c0.52573,0.85065 0,0 0,-1c0,-1 0.48627,-1.17624 1,1c0.4595,1.9465 0,3 0,5c0,0 1.29291,-0.70711 2,0c1.41422,1.41422 1,5 1,9c0,4 0.48627,6.82373 1,9c0.22977,0.97327 0.4588,1.69345 1,3c0.76538,1.84778 1.07611,2.61731 2,3c1.30655,0.5412 1.79395,-0.08743 4,-5c1.83203,-4.07968 4,-6 5,-8c0,0 0,1 0,4c0,4 0,8 0,9c0,1 1.07611,1.38269 2,1c2.61313,-1.0824 2,-4 3,-4c1,0 1,2 1,4c0,2 -0.70709,4.29291 0,5c0.70709,0.70709 1.9176,0.38687 3,3c0.76538,1.84778 1.4588,3.69345 2,5c0.38269,0.92389 2,1 3,1c2,0 5.21167,0.28589 8,-2c3.28101,-2.68979 6.297,-7.61383 9,-10c1.67633,-1.47986 3,-2 3,-2c1,1 2,4 3,7c1,3 1.77023,5.02676 2,6c0.51373,2.17627 2.29291,2.70709 3,2c1.41422,-1.41422 0.69345,-3.4588 2,-4c0.92389,-0.38269 1.4588,0.69345 2,2c1.14804,2.77164 0,3 0,3c1,0 2,0 3,0c0,0 1,0 2,0c1,0 2.14935,0.52573 3,0c1.9021,-1.17557 3.4588,-3.69342 4,-5c0.38269,-0.92389 1,-1 2,-1c1,0 2,0 2,-1c0,-1 0,-3 0,-6c0,-4 1,-9 1,-12c0,-2 0,-2 1,-2c1,0 2,0 3,0c1,0 2,0 2,-2c0,-1 1.29291,-1.70709 2,-1c0.70709,0.70709 0.14935,1.52573 1,1c1.9021,-1.17557 2.51929,-4.5582 5,-8c1.30746,-1.814 2,-3 2,-4c0,-1 0,-2 0,-3c0,-2 0,-3 0,-4l0,-1"/>
  <text fill="#000000" stroke="#000" stroke-width="0" x="19.5" y="240" id="svg_7" font-size="24" font-family="Helvetica, Arial, sans-serif" text-anchor="left" xml:space="preserve">(1, 1, -1, -1, 1)</text>
  <text fill="#000000" stroke-width="0" stroke-opacity="null" fill-opacity="null" x="21.75851" y="118" id="svg_8" font-size="24" font-family="Helvetica, Arial, sans-serif" text-anchor="left" xml:space="preserve" stroke="#000" font-weight="bold">符号 + ノイズ</text>
  <path fill="#000000" stroke-width="1.5" d="m268.46997,300.98068l23.5,-85.2939l23.5,85.2939l-11.74976,0l0,85.70609l-23.50006,0l0,-85.70609l-11.75018,0z" id="svg_2" transform="rotate(112.503 314.97 253.187)" stroke="#000"/>
  <image xlink:href="data:image/png;base64,..." id="svg_10" height="101" width="130" y="24.5" x="377"/>
  <image xlink:href="data:image/png;base64,..." id="svg_11" height="105" width="115" y="205.5" x="380.5"/>
 </g>
</svg>
"""
from IPython.core.display import display, Image, SVG
display(SVG(data))

# %% [markdown]
# # 4.2 ベイズ決定
# ## 受信される信号
#
# $$ \bf{\phi_1} = (1,1,1,-1,-1) ,\bf{\phi_2} = (1,-1,1,-1,1)   $$

# %% [markdown]
# ## Make slides

# %%
# %%bash
# # make slided
# cd //Users/raphael/Copy/works/notebook
# ipython nbconvert "Bayes4 Sildes.ipynb" --to slides --template output_toggle
# Out:
# [NbConvertApp] Using existing profile dir: u'/Users/raphael/.ipython/profile_default'
# [NbConvertApp] Converting notebook Bayes4 Sildes.ipynb to slides
# [NbConvertApp] Support files will be in Bayes4 Sildes_files/
# [NbConvertApp] Loaded template output_toggle.tpl
# /Library/Python/2.7/site-packages/IPython/nbconvert/filters/markdown.py:78: UserWarning: Node.js 0.9.12 or later wasn't found.
# Nbconvert will try to use Pandoc instead.
#   "Nbconvert will try to use Pandoc instead.")
# [NbConvertApp] Writing 489924 bytes to Bayes4 Sildes.slides.html

# %% [markdown]
# ### Tooset URLs
# - http://python.uaca.com:9999/notebooks/Bayes4%20Sildes.ipynb
# - http://python.uaca.com:8011/Bayes4%20Sildes.slides.html#/
# - http://localhost:8022/Bayes4%20Sildes.slides.html#/
# - http://editor.method.ac

# %% [markdown]
# ### Edit SVG at http://editor.method.ac
